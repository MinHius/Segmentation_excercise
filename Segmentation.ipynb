# %%
import kagglehub
bulentsiyah_semantic_drone_dataset_path = kagglehub.dataset_download('bulentsiyah/semantic-drone-dataset')

print('Data source import complete.')

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/semantic-drone-dataset/class_dict_seg.csv
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/173.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/491.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/043.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/248.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/038.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/480.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/236.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/083.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/513.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/074.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/314.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/238.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/222.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/330.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/579.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/303.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/348.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/148.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/403.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/232.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/334.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/177.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/104.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/053.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/376.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/543.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/133.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/162.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/419.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/517.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/398.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/186.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/089.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/261.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/153.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/023.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/167.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/092.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/204.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/296.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/016.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/081.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/538.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/005.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/385.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/031.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/338.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/164.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/521.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/416.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/351.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/011.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/213.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/411.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/302.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/185.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/240.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/281.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/344.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/457.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/493.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/013.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/176.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/124.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/119.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/100.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/500.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/322.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/193.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/420.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/163.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/042.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/138.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/052.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/225.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/561.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/588.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/057.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/192.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/229.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/331.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/313.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/580.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/345.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/171.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/287.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/324.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/145.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/209.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/445.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/311.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/126.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/147.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/075.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/326.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/102.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/431.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/465.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/233.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/200.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/255.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/004.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/515.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/116.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/533.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/299.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/488.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/378.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/130.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/592.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/586.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/443.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/288.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/199.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/112.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/501.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/049.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/150.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/070.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/113.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/332.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/316.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/434.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/529.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/301.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/289.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/170.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/194.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/136.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/018.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/198.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/045.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/161.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/576.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/574.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/367.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/484.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/325.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/002.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/458.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/380.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/446.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/424.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/386.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/549.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/433.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/156.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/040.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/035.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/107.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/372.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/262.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/215.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/414.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/439.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/181.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/412.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/467.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/473.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/587.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/426.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/389.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/068.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/530.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/349.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/335.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/223.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/272.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/598.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/460.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/251.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/174.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/250.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/071.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/440.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/397.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/041.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/157.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/182.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/221.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/383.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/570.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/208.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/137.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/556.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/312.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/239.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/079.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/214.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/122.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/339.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/276.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/051.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/106.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/585.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/356.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/117.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/220.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/391.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/277.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/584.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/425.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/095.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/244.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/329.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/263.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/055.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/166.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/594.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/582.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/320.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/437.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/572.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/455.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/435.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/294.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/088.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/028.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/514.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/026.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/524.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/219.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/073.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/000.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/019.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/003.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/510.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/190.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/165.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/015.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/464.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/202.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/476.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/559.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/447.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/243.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/502.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/509.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/060.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/159.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/563.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/551.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/554.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/596.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/246.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/195.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/479.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/121.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/318.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/216.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/146.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/154.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/063.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/366.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/022.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/188.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/258.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/498.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/290.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/265.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/103.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/298.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/472.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/540.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/109.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/361.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/567.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/526.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/573.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/525.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/080.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/120.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/271.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/363.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/310.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/323.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/118.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/056.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/078.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/393.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/266.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/044.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/179.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/178.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/086.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/160.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/140.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/139.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/172.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/406.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/347.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/001.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/355.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/438.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/430.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/047.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/545.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/409.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/423.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/461.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/375.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/489.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/382.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/444.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/373.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/077.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/463.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/283.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/128.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/158.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/583.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/275.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/591.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/101.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/536.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/135.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/065.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/512.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/123.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/230.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/478.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/442.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/059.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/454.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/410.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/180.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/508.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/499.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/470.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/475.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/564.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/062.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/234.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/252.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/531.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/507.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/565.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/485.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/408.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/569.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/427.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/098.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/537.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/429.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/321.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/235.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/155.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/593.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/228.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/390.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/237.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/451.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/474.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/292.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/421.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/295.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/273.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/413.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/207.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/149.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/535.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/260.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/099.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/206.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/381.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/342.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/346.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/021.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/134.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/590.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/566.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/259.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/341.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/462.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/558.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/111.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/141.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/532.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/309.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/560.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/110.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/544.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/568.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/388.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/008.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/006.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/058.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/257.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/305.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/175.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/518.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/014.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/226.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/428.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/217.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/494.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/452.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/306.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/497.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/304.png
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/208.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/473.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/014.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/537.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/275.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/239.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/150.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/109.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/149.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/521.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/355.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/474.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/501.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/342.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/429.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/544.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/272.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/182.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/215.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/489.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/576.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/185.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/049.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/243.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/153.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/476.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/446.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/425.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/366.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/080.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/062.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/426.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/440.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/260.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/202.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/237.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/273.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/283.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/513.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/564.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/265.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/289.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/118.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/361.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/591.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/443.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/295.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/176.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/334.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/106.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/163.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/113.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/160.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/518.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/463.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/349.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/006.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/234.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/178.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/271.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/251.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/130.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/500.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/156.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/380.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/011.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/558.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/120.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/002.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/290.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/190.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/124.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/089.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/512.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/427.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/313.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/188.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/375.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/480.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/248.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/123.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/028.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/230.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/580.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/408.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/509.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/559.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/538.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/221.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/167.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/515.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/112.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/372.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/388.jpg
# /kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/478.jpg
# ...
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/219.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/073.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/000.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/019.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/003.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/510.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/190.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/165.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/015.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/464.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/202.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/476.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/559.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/447.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/243.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/502.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/509.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/060.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/159.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/563.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/551.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/554.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/596.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/246.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/195.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/479.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/121.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/318.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/216.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/146.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/154.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/063.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/366.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/022.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/188.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/258.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/498.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/290.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/265.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/103.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/298.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/472.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/540.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/109.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/361.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/567.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/526.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/573.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/525.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/080.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/120.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/271.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/363.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/310.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/323.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/118.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/056.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/078.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/393.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/266.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/044.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/179.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/178.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/086.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/160.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/140.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/139.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/172.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/406.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/347.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/001.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/355.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/438.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/430.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/047.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/545.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/409.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/423.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/461.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/375.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/489.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/382.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/444.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/373.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/077.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/463.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/283.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/128.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/158.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/583.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/275.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/591.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/101.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/536.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/135.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/065.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/512.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/123.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/230.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/478.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/442.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/059.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/454.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/410.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/180.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/508.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/499.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/470.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/475.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/564.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/062.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/234.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/252.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/531.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/507.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/565.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/485.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/408.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/569.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/427.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/098.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/537.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/429.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/321.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/235.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/155.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/593.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/228.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/390.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/237.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/451.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/474.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/292.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/421.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/295.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/273.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/413.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/207.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/149.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/535.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/260.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/099.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/206.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/381.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/342.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/346.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/021.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/134.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/590.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/566.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/259.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/341.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/462.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/558.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/111.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/141.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/532.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/309.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/560.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/110.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/544.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/568.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/388.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/008.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/006.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/058.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/257.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/305.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/175.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/518.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/014.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/226.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/428.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/217.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/494.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/452.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/306.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/497.png
# /kaggle/input/semantic-drone-dataset/RGB_color_image_masks/RGB_color_image_masks/304.png

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms as T
import torchvision
import torch.nn.functional as F
from torch.autograd import Variable

from PIL import Image
import cv2
import albumentations as A

import time
import os
from tqdm.notebook import tqdm
# !pip install -q segmentation-models-pytorch
# !pip install -q torchsummary

from torchsummary import summary
import segmentation_models_pytorch as smp

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.5' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
IMAGE_PATH = '/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/original_images/'
MASK_PATH = '/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/label_images_semantic/'

# %%
n_classes = 23

def create_df():
    name = []
    for dirname, _, filenames in os.walk(IMAGE_PATH):
        for filename in filenames:
            name.append(filename.split('.')[0])

    return pd.DataFrame({'id': name}, index = np.arange(0, len(name)))

df = create_df()
print('Total Images: ', len(df))
# Out:
# Total Images:  400

# %%
#split data
X_trainval, X_test = train_test_split(df['id'].values, test_size=0.1, random_state=19)
X_train, X_val = train_test_split(X_trainval, test_size=0.15, random_state=19)

print('Train Size   : ', len(X_train))
print('Val Size     : ', len(X_val))
print('Test Size    : ', len(X_test))
# Out:
# Train Size   :  306
# Val Size     :  54
# Test Size    :  40

# %%
img = Image.open(IMAGE_PATH + df['id'][100] + '.jpg')
mask = Image.open(MASK_PATH + df['id'][100] + '.png')
print('Image Size', np.asarray(img).shape)
print('Mask Size', np.asarray(mask).shape)


plt.imshow(img)
plt.imshow(mask, alpha=0.6)
plt.title('Picture with Mask Appplied')
plt.show()
# Out:
# Image Size (4000, 6000, 3)
# Mask Size (4000, 6000)

# %%
class DroneDataset(Dataset):

    def __init__(self, img_path, mask_path, X, mean, std, transform=None, patch=False):
        self.img_path = img_path
        self.mask_path = mask_path
        self.X = X
        self.transform = transform
        self.patches = patch
        self.mean = mean
        self.std = std

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.jpg')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)

        if self.transform is not None:
            aug = self.transform(image=img, mask=mask)
            img = Image.fromarray(aug['image'])
            mask = aug['mask']

        if self.transform is None:
            img = Image.fromarray(img)

        t = T.Compose([T.ToTensor(), T.Normalize(self.mean, self.std)])
        img = t(img)
        mask = torch.from_numpy(mask).long()

        if self.patches:
            img, mask = self.tiles(img, mask)

        return img, mask

    def tiles(self, img, mask):

        img_patches = img.unfold(1, 512, 512).unfold(2, 768, 768)
        img_patches  = img_patches.contiguous().view(3,-1, 512, 768)
        img_patches = img_patches.permute(1,0,2,3)

        mask_patches = mask.unfold(0, 512, 512).unfold(1, 768, 768)
        mask_patches = mask_patches.contiguous().view(-1, 512, 768)

        return img_patches, mask_patches

# %%
mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]

t_train = A.Compose([A.Resize(704, 1056, interpolation=cv2.INTER_NEAREST), A.HorizontalFlip(), A.VerticalFlip(),
                     A.GridDistortion(p=0.2), A.RandomBrightnessContrast((0,0.5),(0,0.5)),
                     A.GaussNoise()])

t_val = A.Compose([A.Resize(704, 1056, interpolation=cv2.INTER_NEAREST), A.HorizontalFlip(),
                   A.GridDistortion(p=0.2)])

#datasets
train_set = DroneDataset(IMAGE_PATH, MASK_PATH, X_train, mean, std, t_train, patch=False)
val_set = DroneDataset(IMAGE_PATH, MASK_PATH, X_val, mean, std, t_val, patch=False)

#dataloader
batch_size= 3

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True)

# %%
model = smp.Unet('mobilenet_v2', encoder_weights='imagenet', classes=23, activation=None, encoder_depth=5, decoder_channels=[256, 128, 64, 32, 16])

# %%
model
# Out:
# Unet(
#   (encoder): MobileNetV2Encoder(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#       (1): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (2): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (3): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (4): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (7): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (8): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (9): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (10): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (11): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (12): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (13): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (14): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (15): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (16): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (17): InvertedResidual(
#         (conv): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU6(inplace=True)
#           )
#           (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (18): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6(inplace=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): UnetDecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(1376, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): UnetDecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(288, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): UnetDecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(152, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): UnetDecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(80, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): UnetDecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 23, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
def pixel_accuracy(output, mask):
    with torch.no_grad():
        output = torch.argmax(F.softmax(output, dim=1), dim=1)
        correct = torch.eq(output, mask).int()
        accuracy = float(correct.sum()) / float(correct.numel())
    return accuracy

# %%
def mIoU(pred_mask, mask, smooth=1e-10, n_classes=23):
    with torch.no_grad():
        pred_mask = F.softmax(pred_mask, dim=1)
        pred_mask = torch.argmax(pred_mask, dim=1)
        pred_mask = pred_mask.contiguous().view(-1)
        mask = mask.contiguous().view(-1)

        iou_per_class = []
        for clas in range(0, n_classes): #loop per pixel class
            true_class = pred_mask == clas
            true_label = mask == clas

            if true_label.long().sum().item() == 0: #no exist label in this loop
                iou_per_class.append(np.nan)
            else:
                intersect = torch.logical_and(true_class, true_label).sum().float().item()
                union = torch.logical_or(true_class, true_label).sum().float().item()

                iou = (intersect + smooth) / (union +smooth)
                iou_per_class.append(iou)
        return np.nanmean(iou_per_class)

# %%
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def fit(epochs, model, train_loader, val_loader, criterion, optimizer, scheduler, patch=False):
    torch.cuda.empty_cache()
    train_losses = []
    test_losses = []
    val_iou = []; val_acc = []
    train_iou = []; train_acc = []
    lrs = []
    min_loss = np.inf
    decrease = 1 ; not_improve=0

    model.to(device)
    fit_time = time.time()
    for e in range(epochs):
        since = time.time()
        running_loss = 0
        iou_score = 0
        accuracy = 0

        #training loop
        model.train()
        for i, data in enumerate(tqdm(train_loader)):

            #training phase
            image_tiles, mask_tiles = data
            if patch:
                bs, n_tiles, c, h, w = image_tiles.size()

                image_tiles = image_tiles.view(-1,c, h, w)
                mask_tiles = mask_tiles.view(-1, h, w)

            image = image_tiles.to(device); mask = mask_tiles.to(device);

            #forward
            output = model(image)
            loss = criterion(output, mask)

            #evaluation metrics
            iou_score += mIoU(output, mask)
            accuracy += pixel_accuracy(output, mask)

            #backward
            loss.backward()
            optimizer.step() #update weight
            optimizer.zero_grad() #reset gradient

            #step the learning rate
            lrs.append(get_lr(optimizer))
            scheduler.step()

            running_loss += loss.item()

        else:
            model.eval()
            test_loss = 0
            test_accuracy = 0
            val_iou_score = 0

            #validation loop
            with torch.no_grad():
                for i, data in enumerate(tqdm(val_loader)):

                    #reshape to 9 patches from single image, delete batch size
                    image_tiles, mask_tiles = data

                    if patch:
                        bs, n_tiles, c, h, w = image_tiles.size()

                        image_tiles = image_tiles.view(-1,c, h, w)
                        mask_tiles = mask_tiles.view(-1, h, w)

                    image = image_tiles.to(device); mask = mask_tiles.to(device);
                    output = model(image)

                    #evaluation metrics
                    val_iou_score +=  mIoU(output, mask)
                    test_accuracy += pixel_accuracy(output, mask)

                    #loss
                    loss = criterion(output, mask)
                    test_loss += loss.item()

            #calculate mean for each batch
            train_losses.append(running_loss/len(train_loader))
            test_losses.append(test_loss/len(val_loader))

            if min_loss > (test_loss/len(val_loader)):
                print('Loss Decreasing.. {:.3f} >> {:.3f} '.format(min_loss, (test_loss/len(val_loader))))
                min_loss = (test_loss/len(val_loader))
                decrease += 1
                if decrease % 5 == 0:
                    print('saving model...')
                    torch.save(model, 'Unet-Mobilenet_v2_mIoU-{:.3f}.pt'.format(val_iou_score/len(val_loader)))


            if (test_loss/len(val_loader)) > min_loss:
                not_improve += 1
                min_loss = (test_loss/len(val_loader))
                print(f'Loss Not Decrease for {not_improve} time')
                if not_improve == 7:
                    print('Loss not decrease for 7 times, Stop Training')
                    break

            #iou
            val_iou.append(val_iou_score/len(val_loader))
            train_iou.append(iou_score/len(train_loader))
            train_acc.append(accuracy/len(train_loader))
            val_acc.append(test_accuracy/ len(val_loader))
            print("Epoch:{}/{}..".format(e+1, epochs),
                  "Train Loss: {:.3f}..".format(running_loss/len(train_loader)),
                  "Val Loss: {:.3f}..".format(test_loss/len(val_loader)),
                  "Train mIoU:{:.3f}..".format(iou_score/len(train_loader)),
                  "Val mIoU: {:.3f}..".format(val_iou_score/len(val_loader)),
                  "Train Acc:{:.3f}..".format(accuracy/len(train_loader)),
                  "Val Acc:{:.3f}..".format(test_accuracy/len(val_loader)),
                  "Time: {:.2f}m".format((time.time()-since)/60))

    history = {'train_loss' : train_losses, 'val_loss': test_losses,
               'train_miou' :train_iou, 'val_miou':val_iou,
               'train_acc' :train_acc, 'val_acc':val_acc,
               'lrs': lrs}
    print('Total time: {:.2f} m' .format((time.time()- fit_time)/60))
    return history

# %%
max_lr = 1e-3
epoch = 15
weight_decay = 1e-4

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=max_lr, weight_decay=weight_decay)
sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=epoch,
                                            steps_per_epoch=len(train_loader))

history = fit(epoch, model, train_loader, val_loader, criterion, optimizer, sched)
# Out:
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. inf >> 1.960
# Epoch:1/15.. Train Loss: 2.815.. Val Loss: 1.960.. Train mIoU:0.040.. Val mIoU: 0.103.. Train Acc:0.235.. Val Acc:0.563.. Time: 3.65m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 1.960 >> 1.328
# Epoch:2/15.. Train Loss: 1.985.. Val Loss: 1.328.. Train mIoU:0.080.. Val mIoU: 0.118.. Train Acc:0.518.. Val Acc:0.661.. Time: 3.26m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Not Decrease for 1 time
# Epoch:3/15.. Train Loss: 1.709.. Val Loss: 1.394.. Train mIoU:0.094.. Val mIoU: 0.141.. Train Acc:0.536.. Val Acc:0.645.. Time: 3.31m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 1.394 >> 1.111
# Epoch:4/15.. Train Loss: 1.594.. Val Loss: 1.111.. Train mIoU:0.109.. Val mIoU: 0.166.. Train Acc:0.557.. Val Acc:0.703.. Time: 3.30m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Not Decrease for 2 time
# Epoch:5/15.. Train Loss: 1.526.. Val Loss: 1.257.. Train mIoU:0.111.. Val mIoU: 0.130.. Train Acc:0.565.. Val Acc:0.639.. Time: 3.30m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 1.257 >> 1.066
# saving model...
# Epoch:6/15.. Train Loss: 1.487.. Val Loss: 1.066.. Train mIoU:0.114.. Val mIoU: 0.164.. Train Acc:0.564.. Val Acc:0.695.. Time: 3.31m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 1.066 >> 1.027
# Epoch:7/15.. Train Loss: 1.337.. Val Loss: 1.027.. Train mIoU:0.132.. Val mIoU: 0.188.. Train Acc:0.613.. Val Acc:0.730.. Time: 3.31m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 1.027 >> 0.951
# Epoch:8/15.. Train Loss: 1.328.. Val Loss: 0.951.. Train mIoU:0.137.. Val mIoU: 0.186.. Train Acc:0.610.. Val Acc:0.726.. Time: 3.32m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 0.951 >> 0.890
# Epoch:9/15.. Train Loss: 1.225.. Val Loss: 0.890.. Train mIoU:0.153.. Val mIoU: 0.212.. Train Acc:0.639.. Val Acc:0.741.. Time: 3.31m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 0.890 >> 0.868
# Epoch:10/15.. Train Loss: 1.216.. Val Loss: 0.868.. Train mIoU:0.158.. Val mIoU: 0.215.. Train Acc:0.645.. Val Acc:0.753.. Time: 3.32m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 0.868 >> 0.794
# saving model...
# Epoch:11/15.. Train Loss: 1.100.. Val Loss: 0.794.. Train mIoU:0.181.. Val mIoU: 0.232.. Train Acc:0.680.. Val Acc:0.774.. Time: 3.32m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 0.794 >> 0.768
# Epoch:12/15.. Train Loss: 1.068.. Val Loss: 0.768.. Train mIoU:0.187.. Val mIoU: 0.245.. Train Acc:0.684.. Val Acc:0.781.. Time: 3.32m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Not Decrease for 3 time
# Epoch:13/15.. Train Loss: 1.020.. Val Loss: 0.772.. Train mIoU:0.199.. Val mIoU: 0.239.. Train Acc:0.702.. Val Acc:0.778.. Time: 3.31m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Decreasing.. 0.772 >> 0.742
# Epoch:14/15.. Train Loss: 0.970.. Val Loss: 0.742.. Train mIoU:0.208.. Val mIoU: 0.236.. Train Acc:0.716.. Val Acc:0.782.. Time: 3.32m
#   0%|          | 0/102 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# Loss Not Decrease for 4 time
# Epoch:15/15.. Train Loss: 0.979.. Val Loss: 0.744.. Train mIoU:0.205.. Val mIoU: 0.236.. Train Acc:0.711.. Val Acc:0.782.. Time: 3.32m
# Total time: 49.99 m

# %%
def plot_loss(history):
    plt.plot(history['val_loss'], label='val', marker='o')
    plt.plot( history['train_loss'], label='train', marker='o')
    plt.title('Loss per epoch'); plt.ylabel('loss');
    plt.xlabel('epoch')
    plt.legend(), plt.grid()
    plt.show()

def plot_score(history):
    plt.plot(history['train_miou'], label='train_mIoU', marker='*')
    plt.plot(history['val_miou'], label='val_mIoU',  marker='*')
    plt.title('Score per epoch'); plt.ylabel('mean IoU')
    plt.xlabel('epoch')
    plt.legend(), plt.grid()
    plt.show()

def plot_acc(history):
    plt.plot(history['train_acc'], label='train_accuracy', marker='*')
    plt.plot(history['val_acc'], label='val_accuracy',  marker='*')
    plt.title('Accuracy per epoch'); plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(), plt.grid()
    plt.show()

# %%
plot_loss(history)
plot_score(history)
plot_acc(history)

# %%
class DroneTestDataset(Dataset):

    def __init__(self, img_path, mask_path, X, transform=None):
        self.img_path = img_path
        self.mask_path = mask_path
        self.X = X
        self.transform = transform

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        img = cv2.imread(self.img_path + self.X[idx] + '.jpg')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.mask_path + self.X[idx] + '.png', cv2.IMREAD_GRAYSCALE)

        if self.transform is not None:
            aug = self.transform(image=img, mask=mask)
            img = Image.fromarray(aug['image'])
            mask = aug['mask']

        if self.transform is None:
            img = Image.fromarray(img)

        mask = torch.from_numpy(mask).long()

        return img, mask


t_test = A.Resize(768, 1152, interpolation=cv2.INTER_NEAREST)
test_set = DroneTestDataset(IMAGE_PATH, MASK_PATH, X_test, transform=t_test)

# %%
def predict_image_mask_miou(model, image, mask, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]):
    model.eval()
    t = T.Compose([T.ToTensor(), T.Normalize(mean, std)])
    image = t(image)
    model.to(device); image=image.to(device)
    mask = mask.to(device)
    with torch.no_grad():

        image = image.unsqueeze(0)
        mask = mask.unsqueeze(0)

        output = model(image)
        score = mIoU(output, mask)
        masked = torch.argmax(output, dim=1)
        masked = masked.cpu().squeeze(0)
    return masked, score

# %%
def predict_image_mask_pixel(model, image, mask, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]):
    model.eval()
    t = T.Compose([T.ToTensor(), T.Normalize(mean, std)])
    image = t(image)
    model.to(device); image=image.to(device)
    mask = mask.to(device)
    with torch.no_grad():

        image = image.unsqueeze(0)
        mask = mask.unsqueeze(0)

        output = model(image)
        acc = pixel_accuracy(output, mask)
        masked = torch.argmax(output, dim=1)
        masked = masked.cpu().squeeze(0)
    return masked, acc

# %%
image, mask = test_set[3]
pred_mask, score = predict_image_mask_miou(model, image, mask)

# %%
def miou_score(model, test_set):
    score_iou = []
    for i in tqdm(range(len(test_set))):
        img, mask = test_set[i]
        pred_mask, score = predict_image_mask_miou(model, img, mask)
        score_iou.append(score)
    return score_iou

# %%
mob_miou = miou_score(model, test_set)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
def pixel_acc(model, test_set):
    accuracy = []
    for i in tqdm(range(len(test_set))):
        img, mask = test_set[i]
        pred_mask, acc = predict_image_mask_pixel(model, img, mask)
        accuracy.append(acc)
    return accuracy

# %%
mob_acc = pixel_acc(model, test_set)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
ax1.imshow(image)
ax1.set_title('Picture');

ax2.imshow(mask)
ax2.set_title('Ground truth')
ax2.set_axis_off()

ax3.imshow(pred_mask)
ax3.set_title('UNet-MobileNet | mIoU {:.3f}'.format(score))
ax3.set_axis_off()

# %%
image2, mask2 = test_set[4]
pred_mask2, score2 = predict_image_mask_miou(model, image2, mask2)

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20,10))
ax1.imshow(image2)
ax1.set_title('Picture');

ax2.imshow(mask2)
ax2.set_title('Ground truth')
ax2.set_axis_off()

ax3.imshow(pred_mask2)
ax3.set_title('UNet-MobileNet | mIoU {:.3f}'.format(score2))
ax3.set_axis_off()

# %%
print('Test Set mIoU', np.mean(mob_miou))
# Out:
# Test Set mIoU 0.26322647496025137

# %%
print('Test Set Pixel Accuracy', np.mean(mob_acc))
# Out:
# Test Set Pixel Accuracy 0.754364013671875
